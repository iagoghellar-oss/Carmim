# %% [markdown]
# <a href="https://colab.research.google.com/github/iagoghellar-oss/Carmim/blob/main/atividadegit1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = str (input("Nome do aluno: "))

n1 = float (input("Primeira nota"))
n2 = float (input("Segunda nota"))
n3 = float (input("Terceira nota"))

média = n1 + n2 + n3

print ("o aluno", nome,"tirou", média)
# Out:
# Nome do aluno: iago
# Primeira nota7
# Segunda nota2
# Terceira nota1
# o aluno iago tirou 10.0
