# %% [markdown]
# <a href="https://colab.research.google.com/github/iagoghellar-oss/Carmim/blob/main/Carmim1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git --version
# !git config --global user.name iagoghellar-oss
# !git config --global user.email iago.ghellar@sou.unijui.edu.br
# !git config --global init.defaultBranch main
# !git config --global --list
# Out:
# git version 2.34.1
# user.name=iagoghellar-oss
# user.email=iago.ghellar@sou.unijui.edu.br
# init.defaultbranch=main

# %%
# !git clone https://github.com/iagoghellar-oss/Carmim.git
# %cd Carmim
# !ls
# !git status
# !git remote -v
# Out:
# Cloning into 'Carmim'...
# ...
# /content/Carmim
# On branch main
#
# No commits yet
#
# nothing to commit (create/copy files and use "git add" to track)
# origin	https://github.com/iagoghellar-oss/Carmim.git (fetch)
# origin	https://github.com/iagoghellar-oss/Carmim.git (push)

# %%
# !ls
# Out:
# README.md

# %%
# %%writefile README.md
# # Carmim
#
# Arquivos de Carmim: Colab, GitHub e Git
#
# ## Autor
# Iago
# Out:
# Writing README.md

# %%
# !cat README.md
# !git status

# %%
# !git add README.md

# %%
# !git commit -m "updated Carmim README"
# Out:
# [main (root-commit) 17dc069] updated Carmim README
#  1 file changed, 6 insertions(+)
#  create mode 100644 README.md

# %%
# !git push origin main

# %%
# !apt-get -qq update
# !apt-get -qq install gh
# !GH_PROMPT_DISABLED=1 gh auth login --hostname github.com --git-protocol https --web
# !gh auth setup-git
# !gh auth status
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
# ! First copy your one-time code: 30BC-6D7F
# Open this URL to continue in your web browser: https://github.com/login/device
# ✓ Authentication complete.
# - gh config set -h github.com git_protocol https
# ✓ Configured git protocol
# ! Authentication credentials saved in plain text
# ✓ Logged in as iagoghellar-oss
# ! You were already logged in to this account
# github.com
#   ✓ Logged in to github.com account iagoghellar-oss (/root/.config/gh/hosts.yml)
#   - Active account: true
#   - Git operations protocol: https
#   - Token: gho_************************************
#   - Token scopes: 'gist', 'read:org', 'repo'

# %%
# !git push origin main
# Out:
# Enumerating objects: 3, done.
# Counting objects: 100% (3/3), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 290 bytes | 290.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/iagoghellar-oss/Carmim.git
#  * [new branch]      main -> main

# %%
# !git pull origin main
